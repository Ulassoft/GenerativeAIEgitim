# %%
import langchain_openai

# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())
openai_api_key = os.environ["OPENAI_API_KEY"]

# %%
from langchain_openai import ChatOpenAI

chatModel = ChatOpenAI(model="gpt-4o-mini")

messages = [
    ("system", "Uzun yıllardır eğitim sektöründe olan özellikle edebiyat üzerine eğitim veren bir uzmansın. sana sorulan soruları edebi bir dille cevaplayacaksın"),
    ("human", "Merhaba. Nasılsın"),
]

response = chatModel.invoke(messages)

# %%
print(response)
# Out:
# content='Merhaba! Ben çok iyiyim, teşekkür ederim! Sen nasılsın? Okulda neler yapıyorsun?' response_metadata={'token_usage': {'completion_tokens': 29, 'prompt_tokens': 43, 'total_tokens': 72, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'finish_reason': 'stop', 'logprobs': None} id='run-78c065ff-9e8a-4508-8a1c-b262a4ca0c51-0' usage_metadata={'input_tokens': 43, 'output_tokens': 29, 'total_tokens': 72}

# %%
print(response.content)
# Out:
# Merhaba! Ben çok iyiyim, teşekkür ederim! Sen nasılsın? Okulda neler yapıyorsun?
