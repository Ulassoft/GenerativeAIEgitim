# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

# %%
from langchain.llms import HuggingFaceEndpoint

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
hugging_face_token = os.environ["HUGGINGFACE_TOKEN"]

# %%
hugging_face_token
# Out:
# 'XXX'

# %%
llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.3", 
    task="text-generation"  # Bu satır, modelin hangi işlemi yapacağına dair task parametresini belirtir
)

# %%
result=llm.invoke("fotosentez nedir")
result
# Out:
# '\n\nFoto-sentez, bir yöntemdir ki, genellikle şimşekler veya sıvı yüzeylerde sıvı foto-sentetik hammadde üretimi için kullanılır. Bu yöntem, şimşeklerin veya sıvı yüzeylerin yüzeyindeki reaksiyonların sıkıştırılmış hücrelerin kullanılması ile yapılır. Foto-sentez yöntemi, fotosentez reaksiyonlarını kataliz eden katı hücrelere dayanır. Bu hücreler, zincir halinde fotosentez reaksiyonlarını yürütmek için gerekli tüm enzimler ve moleküllerin içinde bulunur.\n\nFoto-sentez yöntemi, enerji tüketimi sınırlarının azalması ve çevresel etkilerin azalması için yaygın olarak kullanılmaktadır. Örneğin, genetik kodlanmış bakteriye dayanan foto-sentetik şimşekler, ultraviyol yapıştırıcıların ve plastiklerin üretiminde yüksek performans sağlar, ayrıca, yüksek miktarda oksijen ve diğer gazların sürüştürülmesi veya tüketilmesi ile enerji tüketimi sınırlarının azalması sağlar.\n\nFoto-sentetik şimşekler, ayrıca, biyomimiksi ve yüksek performanslı optoelektronik cihazların geliştirilmesinde de kullanılır. Örneğin,'
